# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[5,7,4],linewidth=12)

# %%
# ?plt.plot

# %%
x=[1,2,3]
y=[4,5,6]

plt.plot(x,y, linestyle='dashed',color='red')
plt.ylim(bottom=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=[1,2,3]
y=[5,7,4]
plt.plot(x,y,label='1')
plt.xlabel('numbers')
plt.legend()
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-98b65c85e778> in <module>
#       2 y=[5,7,4]
#       3 plt.plot(x,y,label='1')
# ----> 4 plt.xlabel('numbers')
#       5 plt.legend()
#       6 plt.show
#
# TypeError: 'str' object is not callable

# %%
fig, axs=plt.subplots(2)
fig.tight_layout(h_pad=5)

x1=[1,2,3,4]
y1=[8,2,5,6]

x2=[1,2,3,4]
y2=[3,6,1,4]

axs[0].plot(x1,y1)

# %%
import numpy as np
a=np.random.random((4,4))
print(a)
plt.imshow(a,camp="hot")
plt.show
# Out:
# [[0.97570068 0.76430011 0.32073909 0.06245036]
#  [0.24946448 0.27400427 0.27829884 0.68085785]
#  [0.18662234 0.68261739 0.85455989 0.79800441]
#  [0.74063155 0.82207992 0.6920299  0.01513886]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-40c66fee32e0> in <module>
#       2 a=np.random.random((4,4))
#       3 print(a)
# ----> 4 plt.imshow(a,camp="hot")
#       5 plt.show
#
# C:\python\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ...

# %%
# !pip3 install plotly

# %%
2+2
# Out:
# 4

# %%
import plotly.express as px

# %%
px.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-6f2afeb65cb3> in <module>
# ----> 1 px.__version__
#
# AttributeError: module 'plotly.express' has no attribute '__version__'

# %%
flig=px.scatter([{'my_x':[0,1,2,3,4],'my_y':[0,1,4,9,16],x='my_x',y="my_y"})
# Out:
#   File "<ipython-input-38-f58d262e92fc>", line 1
#     flig=px.scatter([{'my_x':[0,1,2,3,4],'my_y':[0,1,4,9,16],x='my_x',y="my_y"})
#                                                               ^
# SyntaxError: invalid syntax

# %%
np.random.randint(1,10,(2,5))
# Out:
# array([[7, 8, 7, 9, 4],
#        [1, 8, 4, 5, 4]])
