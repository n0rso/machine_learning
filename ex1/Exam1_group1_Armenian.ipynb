# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Օգտագործեք pandas module-ը "car_data.csv" dataset-ը  import անելու համար և ստեղծեք pandas dataframe։

# %%
df=pd.read_csv("car_data.csv")
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration num_doors  \
# 0            3                NaN  alfa-romero       gas        std       two
# 1            3                NaN  alfa-romero       gas        std       two
# 2            1                NaN  alfa-romero       gas        std       two
# 3            2              164.0         audi       gas        std      four
# 4            2              164.0         audi       gas        std      four
# ..         ...                ...          ...       ...        ...       ...
# 200         -1               95.0        volvo       gas        std      four
# 201         -1               95.0        volvo       gas      turbo      four
# 202         -1               95.0        volvo       gas        std      four
# 203         -1               95.0        volvo    diesel      turbo      four
# 204         -1               95.0        volvo       gas      turbo      four
#
# ...

# %% [markdown]
# ### Տպեք dataframe-ի առաջին 5 արժեքները։

# %%
df[0:5]
# Out:
#    symboling  normalized_losses         make fuel_type aspiration num_doors  \
# 0          3                NaN  alfa-romero       gas        std       two
# 1          3                NaN  alfa-romero       gas        std       two
# 2          1                NaN  alfa-romero       gas        std       two
# 3          2              164.0         audi       gas        std      four
# 4          2              164.0         audi       gas        std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Որո՞նք են 'make' սյան unique արժեքները։

# %%
print("make column unique values:",df["make"].unique())
# Out:
# make column unique values: ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']

# %% [markdown]
# ### Ո՞ր 'make'-ն ունի ամենամեծ միջին գինը։

# %%
chhaskaca inj petq anem :D

# %% [markdown]
# ### Ստեղծեք նոր dataframe, որը կպարունակի միայն 'wheel_base', 'length', 'width', 'height', 'curb_weight', 'horsepower', 'price' columns-ները։

# %%
df2=df.drop(df.columns.difference(["wheel_base","length","height","curb_weught","horsepower","price"]),axis=1)
df2
# Out:
#      wheel_base  length  height  horsepower    price
# 0          88.6   168.8    48.8       111.0  13495.0
# 1          88.6   168.8    48.8       111.0  16500.0
# 2          94.5   171.2    52.4       154.0  16500.0
# 3          99.8   176.6    54.3       102.0  13950.0
# 4          99.4   176.6    54.3       115.0  17450.0
# ..          ...     ...     ...         ...      ...
# 200       109.1   188.8    55.5       114.0  16845.0
# 201       109.1   188.8    55.5       160.0  19045.0
# 202       109.1   188.8    55.5       134.0  21485.0
# 203       109.1   188.8    55.5       106.0  22470.0
# 204       109.1   188.8    55.5       114.0  22625.0
#
# [205 rows x 5 columns]

# %% [markdown]
# ### Օգտագործեք correlation matrix ու որոշեք թե որ feature-ներն են կորելացված 'price' feature-ի հետ։

# %%
df2.corr()
# Out:
#             wheel_base    length    height  horsepower     price
# wheel_base    1.000000  0.874587  0.589435    0.352297  0.584642
# length        0.874587  1.000000  0.491029    0.555003  0.690628
# height        0.589435  0.491029  1.000000   -0.110711  0.135486
# horsepower    0.352297  0.555003 -0.110711    1.000000  0.810533
# price         0.584642  0.690628  0.135486    0.810533  1.000000

# %%
list_c2=df2.columns.tolist()
list_c2
# Out:
# ['wheel_base', 'length', 'height', 'horsepower', 'price']

# %%
len(list_c2)
list_c2[4]
# Out:
# 'price'

# %%
df2
# Out:
#      wheel_base  length  height  horsepower    price
# 0          88.6   168.8    48.8       111.0  13495.0
# 1          88.6   168.8    48.8       111.0  16500.0
# 2          94.5   171.2    52.4       154.0  16500.0
# 3          99.8   176.6    54.3       102.0  13950.0
# 4          99.4   176.6    54.3       115.0  17450.0
# ..          ...     ...     ...         ...      ...
# 200       109.1   188.8    55.5       114.0  16845.0
# 201       109.1   188.8    55.5       160.0  19045.0
# 202       109.1   188.8    55.5       134.0  21485.0
# 203       109.1   188.8    55.5       106.0  22470.0
# 204       109.1   188.8    55.5       114.0  22625.0
#
# [205 rows x 5 columns]

# %% [markdown]
# ### Գծեք scatter plot-եր (յուրաքանչյուր feature VS price)։ Ընտրեք 1 feature, որն ունի ամենագծային կախվածությունը 'price' feature-ից։

# %%
fig,axs=plt.subplots(len(list_c2)-1,1)
fig.set_figheight(10)
fig.tight_layout(h_pad=5)

for i in range(len(list_c2)-1):
    axs[i].scatter(df2[list_c2[i]],df[list_c2[len(list_c2)-1]])
    axs[i].set_xlabel(list_c2[i])
    axs[i].set_ylabel(list_c2[len(list_c2)-1])

# %% [markdown]
# ### Մենք կօգտագործենք 'price'-ը որպես target variable, ինչպես նաև Ձեր ընտրած feature-ը ու կկառուցենք linear regression model.

# %%
##vercnenq horsepower feature

# %% [markdown]
# ### Dataframe-ից վերցրեք միայն Ձեր ընտրած feature-ն ու 'price' feature-ը։ Ստուգեք թե արդյոք dataframe-ը պարունակում է Nan արժեքներ և լցրեք դրանք (fill) Ձեր ցանկացած մեթոդով։

# %%
df3=df2[[list_c2[3],list_c2[4]]]
df3
# Out:
#      horsepower    price
# 0         111.0  13495.0
# 1         111.0  16500.0
# 2         154.0  16500.0
# 3         102.0  13950.0
# 4         115.0  17450.0
# ..          ...      ...
# 200       114.0  16845.0
# 201       160.0  19045.0
# 202       134.0  21485.0
# 203       106.0  22470.0
# 204       114.0  22625.0
#
# [205 rows x 2 columns]

# %%
df3=df3.fillna(0)
df3
# Out:
#      horsepower    price
# 0         111.0  13495.0
# 1         111.0  16500.0
# 2         154.0  16500.0
# 3         102.0  13950.0
# 4         115.0  17450.0
# ..          ...      ...
# 200       114.0  16845.0
# 201       160.0  19045.0
# 202       134.0  21485.0
# 203       106.0  22470.0
# 204       114.0  22625.0
#
# [205 rows x 2 columns]

# %%
list_c3=df3.columns.tolist()
list_c3
# Out:
# ['horsepower', 'price']

# %% [markdown]
# ### Բաժանեք տվյալները train և test dataset-երի 80:20 հարաբերակցությամբ։

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest=train_test_split(df3[df3.columns.difference([list_c3[1]])],df3[list_c3[1]],test_size=0.2,random_state=42)
len(xTrain),len(xTest)
# Out:
# (164, 41)

# %%
xTest
# Out:
#      horsepower
# 15        182.0
# 9         160.0
# 100        97.0
# 132       110.0
# 68        123.0
# 95         69.0
# 159        56.0
# 162        70.0
# 147        94.0
# 182        52.0
# 191       110.0
# 164        70.0
# 65        120.0
# 175        92.0
# 73        184.0
# 152        62.0
# 18         48.0
# 82        145.0
# 86         88.0
# 143        94.0
# 60         84.0
# 101       152.0
# 98         69.0
# 30         58.0
# 25         68.0
# 16        182.0
# 168       116.0
# 195       114.0
# 97         69.0
# 194       114.0
# 67        123.0
# 120        68.0
# 154        62.0
# 202       134.0
# 79        102.0
# 69        123.0
# 145       111.0
# 55        101.0
# 45         70.0
# 84        145.0
# 146        82.0

# %%
yTest
# Out:
# 15     30760.0
# 9          0.0
# 100     9549.0
# 132    11850.0
# 68     28248.0
# 95      7799.0
# 159     7788.0
# 162     9258.0
# 147    10198.0
# 182     7775.0
# 191    13295.0
# 164     8238.0
# 65     18280.0
# 175     9988.0
# 73     40960.0
# 152     6488.0
# 18      5151.0
# 82     12629.0
# 86      8189.0
# 143     9960.0
# 60      8495.0
# 101    13499.0
# 98      8249.0
# 30      6479.0
# 25      6692.0
# 16     41315.0
# 168     9639.0
# 195    13415.0
# 97      7999.0
# 194    12940.0
# 67     25552.0
# 120     6229.0
# 154     7898.0
# 202    21485.0
# 79      7689.0
# 69     28176.0
# 145    11259.0
# 55     10945.0
# 45         0.0
# 84     14489.0
# 146     7463.0
# Name: price, dtype: float64

# %% [markdown]
# ### Import արեք համապատասխան գրադարաններ fit արեք linear regression մոդել մեր տվյալներին։ Prediction կատարեք test տվյալների վրա։

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression().fit(xTrain,yTrain)
b0=model.intercept_
b1=model.coef_

# %%
b0,b1
# Out:
# (-234.7465472718286, array([127.52759895]))

# %%
plt1=plt.scatter(x,y,color="r")
plt2=plt.plot(x,b0+b1*x,color="k",)
plt.xlabel(list_c3[0])
plt.ylabel(list_c3[1])
plt.show()

# %% [markdown]
# ### Import արեք համապատասխան library-ներ ու հաշվեք root mean squared error (RMSE) test տվյալների վրա։

# %%
from sklearn.metrics import mean_squared_error
y_pred=model.predict(xTest)

rmse=np.sqrt(mean_squared_error(yTest,y_pred))
print("Rmse:",rmse)
# Out:
# Rmse: 6710.366197543217

# %% [markdown]
# ### Ուսումնասիրեք 'price' սյան տվյալներն ու որոշեք (ասեք) թե որքանով լավ արդյունք եք ստացել նախորդ առաջադրանքում։

# %%
df[list_c3[1]]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
im karciqov etqanle lav arcyunq chi :D
namanavand vor squared errorna 6710,vory arden prici arjeqnieri het hamematac zgalit viya(((

# %% [markdown]
# ### (Extra) Փորձեք օգտագործել ավելի շատ feature-ներ, արդյո՞ք ավելի լավ արդյունք եք ստանում։

# %%
es chhascreci
